# %%
import pandas as pd

# %%
file = '1.txt'
car = pd.read_csv(file)
car = car.sort_values('#id',ascending=True)
car
# Out:
#           #id  from    to  speed planTime)
# 36914   10000   894  1019      6        2)
# 22830   10002   554  1180      8       17)
# 645     10003   998   552     10       18)
# 12043   10005  1567   493      6        2)
# 33718   10006  1019   581      4       24)
# 59701   10008  1608  1855     16       29)
# 1813    10011   123  1238     10        4)
# 37624   10012  1934  1019     14       14)
# 43551   10013   211  1085      8        7)
# 29168   10014   541  1834      6        4)
# 40944   10015   863  1697     14       21)
# 25590   10019  1531   667      4       24)
# 49567   10023   297  1432     14       10)
# 20045   10025  1228  1896      8       29)
# 36106   10029   977   902      6        2)
# 52746   10030   661   834     12        6)
# 60789   10034   123  1671     12       11)
# 45381   10035   635  1834      6        5)
# 42060   10036  1580   834     10       17)
# 11389   10037  1197   138     16        7)
# 29408   10038   834  1197     16       25)
# ...

# %%
car['planTime)'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c47b3a3059a3> in <module>()
# ----> 1 car['planTime)'].value_counts()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
car['speed'].value_counts()
# Out:
# 6    2584
# 8    2566
# 4    2548
# 2    2542
# Name: speed, dtype: int64

# %%
pd.set_option('display.max_row',100)
car['from'].value_counts()
# Out:
# 53    195
# 64    186
# 7     184
# 17    183
# 21    182
# 61    177
# 36    175
# 51    175
# 60    174
# 56    173
# 3     173
# 52    173
# 43    171
# 16    171
# 44    169
# 29    167
# 62    166
# 13    166
# 59    165
# 49    163
# 63    163
# 8     163
# 22    163
# 48    161
# 35    160
# 24    160
# 34    160
# 50    160
# 38    160
# 6     159
# 1     159
# 41    159
# 18    159
# 58    158
# 9     157
# 42    157
# 20    157
# 14    157
# 2     156
# 30    156
# 27    156
# 37    155
# 11    155
# 26    154
# 45    153
# 57    153
# 39    152
# 23    152
# 32    151
# 55    151
# 12    150
# 5     150
# 25    150
# 15    149
# 4     149
# 47    149
# 10    148
# 46    147
# 40    147
# 54    145
# 19    141
# 28    141
# 33    136
# 31    134
# Name: from, dtype: int64

# %%
gp=car.groupby(by=['speed','planTime)'])
gp.size()
# Out:
# speed  planTime)
# 2       1)          219
#         10)         257
#         2)          244
#         3)          267
#         4)          266
#         5)          285
#         6)          259
#         7)          247
#         8)          237
#         9)          261
# 4       1)          304
#         10)         251
#         2)          229
#         3)          238
#         4)          276
#         5)          246
#         6)          248
#         7)          267
#         8)          260
#         9)          229
# 6       1)          281
#         10)         245
#         2)          268
#         3)          243
#         4)          239
#         5)          270
#         6)          236
#         7)          254
#         8)          267
#         9)          281
# 8       1)          247
#         10)         254
#         2)          266
#         3)          234
#         4)          266
#         5)          263
#         6)          269
# ...
